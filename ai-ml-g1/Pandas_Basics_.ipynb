# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhawaldwivedi/Bsc-3rd-sem-python-mmdu/blob/main/ai-ml-g1/Pandas_Basics_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# numpy= statistical analysis
# pandas = data manipulation

# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
data = [1,2,3,4]
arr = np.array(data)

# %%
arr
# Out:
# array([1, 2, 3, 4])

# %%
s =pd.Series(data)
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
dct = {'a':1,'b':2,'c':3}
series_dct = pd.Series(dct)
series_dct
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
print(type(series_dct))
# Out:
# <class 'pandas.core.series.Series'>

# %%
data = [1,2,3]
index = ['a','b','c']
series = pd.Series(data,index)
series
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
# dataframe ( dictionary of list)
data = {'Name':['Krish','Dhawal','John'],
        'Age':[23,34,45],
        'City':['Noida','New York','Florida']
        }
df = pd.DataFrame(data)
df
# Out:
#      Name  Age      City
# 0   Krish   23     Noida
# 1  Dhawal   34  New York
# 2    John   45   Florida

# %%
df['City']
# Out:
# 0       Noida
# 1    New York
# 2     Florida
# Name: City, dtype: object

# %%
# loc[row index,column index]
print(df.loc[1,'Age'])
# Out:
# 34

# %%
print(df.loc[1,'Age'])

# %%
# iloc - integer based indexing
print(df.iloc[0,1])
# print(df.iloc[1,2])
# Out:
# 23

# %%
print(df.at[2,'Age'])
# Out:
# 45

# %%
print(df.iat[2,2])
# Out:
# Florida

# %%
df
# Out:
#      Name  Age      City
# 0   Krish   23     Noida
# 1  Dhawal   34  New York
# 2    John   45   Florida

# %%
# adding a column
df['Salary'] = [1000,2000,3000]

# %%
df
# Out:
#      Name  Age      City  Salary
# 0   Krish   23     Noida    1000
# 1  Dhawal   34  New York    2000
# 2    John   45   Florida    3000

# %%
# drop a column
df.drop('Salary',axis =1 ,inplace= True)

# %%
df
# Out:
#      Name  Age      City
# 0   Krish   23     Noida
# 1  Dhawal   34  New York
# 2    John   45   Florida

# %%
df.drop(0,axis=0,inplace=True)

# %%
df
# Out:
#      Name  Age      City
# 1  Dhawal   34  New York
# 2    John   45   Florida

# %%
df['Age']= df['Age']+1
df
# Out:
#      Name  Age      City
# 1  Dhawal   35  New York
# 2    John   46   Florida

# %%
# read the csv file
df = pd.read_csv('/content/sales_data.csv')

# %%
# performing analysis
df
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 1             10002  2024-01-02  Home Appliances
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %%
df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
df.tail()
# Out:
#      Transaction ID        Date Product Category  \
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 235  Nespresso Vertuo Next Coffee and Espresso Maker           1      159.99
# 236                        Nike Air Force 1 Sneakers           3       90.00
# 237           The Handmaid's Tale by Margaret Atwood           3       10.99
# 238             Sunday Riley Luna Sleeping Night Oil           1       55.00
# 239                       Yeti Rambler 20 oz Tumbler           2       29.99
#
#      Total Revenue         Region Payment Method
# 235         159.99         Europe         PayPal
# 236         270.00           Asia     Debit Card
# 237          32.97  North America    Credit Card
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    240 non-null    int64
#  1   Date              240 non-null    object
#  2   Product Category  240 non-null    object
#  3   Product Name      240 non-null    object
#  4   Units Sold        240 non-null    int64
#  5   Unit Price        240 non-null    float64
#  6   Total Revenue     240 non-null    float64
#  7   Region            240 non-null    object
#  8   Payment Method    240 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 17.0+ KB

# %%
df.shape
# Out:
# (240, 9)

# %%
df.describe()
# Out:
#        Transaction ID  Units Sold   Unit Price  Total Revenue
# count       240.00000  240.000000   240.000000     240.000000
# mean      10120.50000    2.158333   236.395583     335.699375
# std          69.42622    1.322454   429.446695     485.804469
# min       10001.00000    1.000000     6.500000       6.500000
# 25%       10060.75000    1.000000    29.500000      62.965000
# 50%       10120.50000    2.000000    89.990000     179.970000
# 75%       10180.25000    3.000000   249.990000     399.225000
# max       10240.00000   10.000000  3899.990000    3899.990000

# %%
# checking for null values
df.isnull()
# Out:
#      Transaction ID   Date  Product Category  Product Name  Units Sold  \
# 0             False  False             False         False       False
# 1             False  False             False         False       False
# 2             False  False             False         False       False
# 3             False  False             False         False       False
# 4             False  False             False         False       False
# ..              ...    ...               ...           ...         ...
# 235           False  False             False         False       False
# 236           False  False             False         False       False
# 237           False  False             False         False       False
# 238           False  False             False         False       False
# 239           False  False             False         False       False
#
#      Unit Price  Total Revenue  Region  Payment Method
# 0         False          False   False           False
# ...

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Product Category    0
# Product Name        0
# Units Sold          0
# Unit Price          0
# Total Revenue       0
# Region              0
# Payment Method      0
# dtype: int64

# %%
df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
# show only data with region = pacific
df[df['Region']== 'North America']
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 3             10004  2024-01-04            Books
# 6             10007  2024-01-07      Electronics
# 9             10010  2024-01-10            Books
# 12            10013  2024-01-13      Electronics
# ..              ...         ...              ...
# 225           10226  2024-08-13            Books
# 228           10229  2024-08-16      Electronics
# 231           10232  2024-08-19            Books
# 234           10235  2024-08-22      Electronics
# 237           10238  2024-08-25            Books
#
#                                     Product Name  Units Sold  Unit Price  \
# 0                                  iPhone 14 Pro           2      999.99
# 3                              The Da Vinci Code           4       15.99
# 6                            MacBook Pro 16-inch           1     2499.99
# 9                          Dune by Frank Herbert           2       25.99
# ...

# %%
# show only data with region = Europe
df[df['Region']== 'Europe']
# Out:
#      Transaction ID        Date Product Category  \
# 1             10002  2024-01-02  Home Appliances
# 4             10005  2024-01-05  Beauty Products
# 7             10008  2024-01-08  Home Appliances
# 10            10011  2024-01-11  Beauty Products
# 13            10014  2024-01-14  Home Appliances
# ..              ...         ...              ...
# 226           10227  2024-08-14  Beauty Products
# 229           10230  2024-08-17  Home Appliances
# 232           10233  2024-08-20  Beauty Products
# 235           10236  2024-08-23  Home Appliances
# 238           10239  2024-08-26  Beauty Products
#
#                                         Product Name  Units Sold  Unit Price  \
# 1                                   Dyson V11 Vacuum           1      499.99
# 4                            Neutrogena Skincare Set           1       89.99
# 7                               Blueair Classic 480i           2      599.99
# ...

# %%
# sort by column
df.sort_values(by = "Total Revenue",ascending = False)
# Out:
#      Transaction ID        Date Product Category  \
# 102           10103  2024-04-12      Electronics
# 85            10086  2024-03-26  Home Appliances
# 6             10007  2024-01-07      Electronics
# 216           10217  2024-08-04      Electronics
# 0             10001  2024-01-01      Electronics
# ..              ...         ...              ...
# 166           10167  2024-06-15  Beauty Products
# 112           10113  2024-04-22  Beauty Products
# 136           10137  2024-05-16  Beauty Products
# 226           10227  2024-08-14  Beauty Products
# 106           10107  2024-04-16  Beauty Products
#
#                                     Product Name  Units Sold  Unit Price  \
# 102                          Canon EOS R5 Camera           1     3899.99
# 85                                    LG OLED TV           2     1299.99
# 6                            MacBook Pro 16-inch           1     2499.99
# 216                    Apple MacBook Pro 16-inch           1     2399.00
# ...

# %%
# find total revenue per region
df.groupby('Product Category')['Total Revenue'].sum().sort_values(ascending = False).head()
# Out:
# Product Category
# Electronics        34982.41
# Home Appliances    18646.16
# Sports             14326.52
# Clothing            8128.93
# Beauty Products     2621.90
# Name: Total Revenue, dtype: float64

# %%
# payment methods per region
df.groupby('Payment Method')['Total Revenue'].sum()
# Out:
# Payment Method
# Credit Card    51170.86
# Debit Card      8128.93
# PayPal         21268.06
# Name: Total Revenue, dtype: float64

# %%
# revenue per category
df.groupby('Region')['Total Revenue'].sum()
# Out:
# Region
# Asia             22455.45
# Europe           21268.06
# North America    36844.34
# Name: Total Revenue, dtype: float64

# %%
# filter data based on north america

na = df[df['Region']=='North America']
na

# %%
# count the diff product category
unique_prod_cat = df['Product Category'].unique()
print(unique_prod_cat)

# %%
unique_prod_cat = df['Region'].nunique()
print(unique_prod_cat)

# %%
# display only product name and total revenue where unit sold is less than 5

# %%
# find top 3 products with highest total revenue , sort it desc
